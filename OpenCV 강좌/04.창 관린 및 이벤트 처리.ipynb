# %% [markdown]
# ## **04.창 관리 및 이벤트 처리**

# %% [markdown]
# ### **창 관리**

# %%
import cv2

file_path = './asset/img/03.png'
img = cv2.imread(file_path)                            # 이미지를 기본 값으로 읽기
img_gray = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE) # 이미지를 그레이 스케일로 읽기

cv2.namedWindow('origin')                               # origin 이름으로 창 생성
cv2.namedWindow('gray', cv2.WINDOW_NORMAL)              # gray 이름으로 창 생성
cv2.imshow('origin', img)                               # origin 창에 이미지 표시
cv2.imshow('gray', img_gray)                            # gray 창에 이미지 표시

cv2.moveWindow('origin', 0, 0)                          # 창 위치 변경
cv2.moveWindow('gray', 100, 100)                        # 창 위치 변경

cv2.waitKey(0)                                          # 아무키나 누르면
cv2.resizeWindow('origin', 200, 200)                    # 창 크기 변경 (변경 안됨)
cv2.resizeWindow('gray', 100, 100)                      # 창 크기 변경 (변경 됨))

cv2.waitKey(0)                                          # 아무키나 누르면
cv2.destroyWindow("gray")                               # gray 창 닫기

cv2.waitKey(0)                                          # 아무키나 누르면
cv2.destroyAllWindows()                                 # 모든 창 닫기

# %% [markdown]
# ### **키보드 이벤트 처리**

# %%
# 키 이벤트 처리 (event_key.py)

import cv2
import numpy as np

img_file = "./asset/img/03.png" 
img = cv2.imread(img_file) 
title = 'IMG'                   # 창 이름 
x, y = 100, 100                 # 최초 좌표

while True:
    cv2.imshow(title, img)
    cv2.moveWindow(title, x, y)
    key = cv2.waitKey(0) & 0xFF # 키보드 입력을 무한 대기, 8비트 마스크처리
    print(key, chr(key))        # 키보드 입력 값,  문자 값 출력
    if key == ord('a'):         # 'h' 키 이면 좌로 이동
        x -= 18
        cv2.moveWindow(title, x, y ) 
    elif key == ord('s'):       # 'j' 키 이면 아래로 이동
        y += 18
        cv2.moveWindow(title, x, y ) 
    elif key == ord('w'):       # 'k' 키 이면 위로 이동
        y -= 18
        cv2.moveWindow(title, x, y ) 
    elif key == ord('d'):       # 'l' 키 이면 오른쪽으로 이동
        x += 18
        cv2.moveWindow(title, x, y ) 
    elif key == ord('r'):       
        num_way = np.random.randint(-50, 50, size=2)
        x += int(num_way[0])    
        y += int(num_way[1])
        cv2.moveWindow(title, x, y ) 
    elif key == ord('q') or key == 27: # 'q' 이거나 'esc' 이면 종료
        cv2.destroyAllWindows()
        break
# Out:
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 114 r
# 27

# %% [markdown]
# ### **마우스 이벤트 처리**

# %%
import numpy as np
num_BGR = np.random.randint(0, 255, size=3)
print(type(num_BGR[0]))
# Out:
# <class 'numpy.int32'>

# %%
# 마우스 이벤트로 원 그리기 (event_mouse_circle.py)

import cv2
import numpy as np

title = 'mouse event'                   # 창 제목
img = cv2.imread('./asset/img/02.png') # 백색 이미지 읽기
cv2.imshow(title, img)                  # 백색 이미지 표시

def onMouse(event, x, y, flags, param): # 아무스 콜백 함수 구현 ---①
    # print(event, x, y, )                # 파라미터 출력
    num_size = np.random.randint(1, 30, size=1)
    num_BGR = np.random.randint(0, 255, size=3)
    if event == cv2.EVENT_LBUTTONDOWN:  # 왼쪽 버튼 누름인 경우 ---②
        cv2.circle(img, (x,y), int(num_size[0]), ((int(num_BGR[0]),int(num_BGR[1]),int(num_BGR[2]))), -1) # 지름 30 크기의 검은색 원을 해당 좌표에 그림
        cv2.imshow(title, img)          # 그려진 이미지를 다시 표시 ---③

cv2.setMouseCallback(title, onMouse)    # 마우스 콜백 함수를 GUI 윈도우에 등록 ---④

while True:
    if cv2.waitKey(0) & 0xFF == 27:     # esc로 종료
        break
cv2.destroyAllWindows()

# %%
# flags를 활용하여 원 그리기 (event_mouse_circle_flag.py)

import cv2

title = 'mouse event'                   # 창 제목
img = cv2.imread('./asset/img/02.png') # 백색 이미지 읽기
cv2.imshow(title, img)                  # 백색 이미지 표시

colors = {'black':(0,0,0),
         'red' : (0,0,255),
         'blue':(255,0,0),
         'green': (0,255,0) } # 색상 미리 정의

def onMouse(event, x, y, flags, param): # 아무스 콜백 함수 구현 ---①
    print(event, x, y, flags)                # 파라미터 출력
    color = colors['black']
    if event == cv2.EVENT_LBUTTONDOWN:  # 왼쪽 버튼 누름인 경우 ---②
        # 컨트롤키와 쉬프트 키를 모두 누른 경우
        if flags & cv2.EVENT_FLAG_CTRLKEY and flags & cv2.EVENT_FLAG_SHIFTKEY : 
            color = colors['green']
        elif flags & cv2.EVENT_FLAG_SHIFTKEY : # 쉬프트 키를 누른 경우
            color = colors['blue']
        elif flags & cv2.EVENT_FLAG_CTRLKEY : # 컨트롤 키를 누른 경우
            color = colors['red']
        # 지름 30 크기의 검은색 원을 해당 좌표에 그림
        cv2.circle(img, (x,y), 30, color, -1) 
        cv2.imshow(title, img)          # 그려진 이미지를 다시 표시 ---③

cv2.setMouseCallback(title, onMouse)    # 마우스 콜백 함수를 GUI 윈도우에 등록 ---④

while True:
    if cv2.waitKey(0) & 0xFF == 27:     # esc로 종료
        break
cv2.destroyAllWindows()
# Out:
# 0 232 489 0
# 0 232 481 0
# 0 232 477 0
# 0 232 473 0
# 0 232 465 0
# 0 230 456 0
# 0 229 447 0
# 0 229 441 0
# 0 229 437 0
# 0 229 434 0
# 0 229 426 0
# 0 229 420 0
# 0 229 410 8
# 0 229 404 8
# 0 229 398 8
# 0 229 396 8
# 0 229 395 8
# 0 231 392 8
# 0 233 386 8
# 0 238 379 8
# 0 242 362 8
# 0 242 344 8
# 0 242 325 8
# 0 242 317 8
# 0 242 257 8
# 0 238 230 8
# 0 226 160 8
# 0 223 141 8
